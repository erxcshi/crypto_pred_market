# %%
import pandas as pd
import polars as pl
from pathlib import Path

# %%
data_files_dir = Path.cwd().parent / 'data_gather' / 'data_files'
# df = pd.read_csv(data_files_dir / 'kalshi_markets.csv')
data_files_dir
# Out:
# WindowsPath('c:/Users/erics/courses/gradml1/crypto_pred_market/data_gather/data_files')

# %%
df = pl.scan_csv(data_files_dir / 'kalshi_markets.csv').collect()
df.head()
# Out:
# shape: (5, 17)
# ┌─────┬──────────────┬──────┬──────────────┬───┬────────────┬──────────────┬────────┬──────────────┐
# │ id  ┆ curr_time    ┆ coin ┆ open_time    ┆ … ┆ cap_strike ┆ strike_type  ┆ volume ┆ volume_24h_f │
# │ --- ┆ ---          ┆ ---  ┆ ---          ┆   ┆ ---        ┆ ---          ┆ ---    ┆ p            │
# │ i64 ┆ str          ┆ str  ┆ str          ┆   ┆ str        ┆ str          ┆ str    ┆ ---          │
# │     ┆              ┆      ┆              ┆   ┆            ┆              ┆        ┆ f64          │
# ╞═════╪══════════════╪══════╪══════════════╪═══╪════════════╪══════════════╪════════╪══════════════╡
# │ 0   ┆ 2026-03-23   ┆ SOL  ┆ 2026-03-23   ┆ … ┆ null       ┆ greater_or_e ┆ null   ┆ 0.0          │
# │     ┆ 06:21:16.232 ┆      ┆ 06:15:00+00: ┆   ┆            ┆ qual         ┆        ┆              │
# │     ┆ 547+00:…     ┆      ┆ 00           ┆   ┆            ┆              ┆        ┆              │
# ...
